# %%
#data cleaning challenge 1 
#2024-03-10
#https://www.kaggle.com/code/chrisbow/cleaning-data-with-python-challenge-day-1

# %%
#ran into environment problem when importing libraries
#problem identified in anaconda and python version, both should be conda
#https://stackoverflow.com/questions/40185437/no-module-named-numpy-visual-studio-code

# %%
import numpy as np #for linear algebra
import pandas as pd #for data processing, reading files  

sfPermits = pd.read_csv('/Users/wuchunting/Desktop/python/data cleaning challenge 1/data file/Building_Permits.csv')

# set seed for reproducibility
np.random.seed(0)
# Out:
# /Users/wuchunting/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#checking samples
sfPermits.sample(10)

# %%
# Calculate percentage of cells in dataframe

# function .shape returns the tuple of an array (3,3) for example
# the product returns the result of 3*3, thus calculate the nb of cells of the dataframe
totalCells = np.product(sfPermits.shape)

#get nb of null cells by column
missingCellCount = sfPermits.isnull().sum()

#get total nb of missing cell
totalMissingCellCount = missingCellCount.sum()

print('Building_Permits dataset contains',round((totalMissingCellCount/totalCells)*100,2),'%','missing cells')
# Out:
# Building_Permits dataset contains 26.26 % missing cells

# %%
missingCount = sfPermits[['Street Number Suffix', 'Zipcode']]

totalCount_streetNumberSuffix = ny.product(sfPermits['Street Number Suffix'].shape)
missingCount_streetNumberSuffix = sfPermits[['Street Number Suffix']].isnull().sum()

totalCount_zipCode = ny.product(sfPermits['Zipcode'].shape)
missingCount_zipCode = sfPermits[['Zipcode']].isnull().sum()

print('Building_Permits dataset column Street Number Suffix contains',round((missingCount_streetNumberSuffix/totalCount_streetNumberSuffix )*100,2),'%','missing cells')
print('Building_Permits dataset column Zipcode contains',round((missingCount_zipCode /totalCount_zipCode )*100,2),'%','missing cells')
#print(missingCount_streetNumberSuffix)
#print(missingCount_zipCode)
# Out:
# Building_Permits dataset column Street Number Suffix contains Street Number Suffix    98.89
# dtype: float64 % missing cells
# Building_Permits dataset column Zipcode contains Zipcode    0.86
# dtype: float64 % missing cells

# %%
#removing rows with null value using pandas.dropna()
sfPermits.dropna()

#all dataset removed
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 43 columns]

# %%
#removing columns with null value using pandas.dropna(axis = 1)  
sfPermitsCleanCol = sfPermits.dropna(axis=1)

#showing column numbers after dropping null columns
sfPermitsCleanCol.head(0).shape[1]
# Out:
# 12

# %%
#comparing dataset initial columns num vs cleaned columns num

print('Initial sfPermits column number =', sfPermits.head(0).shape[1])
print('Dropped null column sfPermits column number =', sfPermitsCleanCol.head(0).shape[1])

print('dropped column by {}%'.format(round(((sfPermitsCleanCol.head(0).shape[1]/sfPermits.head(0).shape[1])*100),2)))
# Out:
# Initial sfPermits column number = 43
# Dropped null column sfPermits column number = 12
# dropped column by 27.91%

# %%
#to avoid sacraficing all null with 0 using pandas.fillna()

inputsfPermits = sfPermits.fillna(method='ffill',axis=0).fillna(0)
inputsfPermits
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %%
#test
totalCells = np.product(sfPermits,axis = None)
totalCells
# Out:
# Permit Type                   0.0
# Street Number                 0.0
# Unit                          0.0
# Number of Existing Stories    NaN
# Number of Proposed Stories    NaN
# Estimated Cost                inf
# Revised Cost                  0.0
# Existing Units                0.0
# Proposed Units                0.0
# Plansets                      0.0
# Existing Construction Type    inf
# Proposed Construction Type    inf
# Supervisor District           inf
# Zipcode                       inf
# Record ID                     0.0
# dtype: float64
